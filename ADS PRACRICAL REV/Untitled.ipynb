# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MARKS2.csv')

# %%
df.head()
# Out:
#    ROLL NO  NAME   ADS  SMA   DC   EM  TOTAL CLASS
# 0        1  LEENA   50   40   50   60    200  PASS
# 1        2  REENA   40   40  150   80    210  PASS
# 2        3  SEENA   30   30   70  130    120  FAIL
# 3        4  MEENA   10  110   50   50    120  FAIL
# 4        5  JEENA   50   50   50   50    200  PASS

# %%
plt.barh(df['NAME '], df['TOTAL'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.hist(df['TOTAL'], edgecolor='black')
# Out:
# (array([2., 2., 1., 0., 2., 7., 2., 1., 2., 1.]),
#  array([ 90., 112., 134., 156., 178., 200., 222., 244., 266., 288., 310.]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(df['TOTAL'], labels = df['NAME '])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a8e3d09a90>,
# ...
#  [Text(1.0860141201866824, 0.17485231126623996, 'LEENA'),
#   Text(0.9721750560136958, 0.5146607236469164, 'REENA'),
#   Text(0.8046487219504628, 0.7500269556912518, 'SEENA'),
#   Text(0.6471318769536347, 0.8895056682396499, 'MEENA'),
#   Text(0.40140804269250857, 1.0241443175948248, 'JEENA'),
#   Text(0.06843864398450342, 1.0978689138551845, 'TEENA'),
#   Text(-0.32183276469306216, 1.0518667556159478, 'HEENA'),
#   Text(-0.6314134512005158, 0.9007313992767512, 'VEENA'),
#   Text(-0.8629782267509791, 0.6821059889443398, 'NEENA'),
#   Text(-1.0690303471133096, 0.25917970011325536, 'BEENA'),
#   Text(-1.0842895931137282, -0.1852459939250138, 'RAMESH'),
#   Text(-0.9754415127761944, -0.5084425780291119, 'SURESH'),
#   Text(-0.7474541577082209, -0.8070392073032724, 'JAYESH'),
#   Text(-0.5099990849570784, -0.974628613033161, 'PARESH'),
#   Text(-0.2711090057225857, -1.0660674964635735, 'MOLLY'),
# ...

# %%
data = (df['ADS'], df['SMA'], df['EM'], df['DC'])

# %%
hm = sns.heatmap(data = data)
plt.show()

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a8e64ad8d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a8e64ae950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a8e3c69750>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1a8e651d190>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a8e651da90>,
# ...
#  'means': []}

# %%
plt.violinplot(data)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1a8e6031010>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1a8e656a610>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1a8e65865d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1a8e65c6c90>}

# %%
plt.plot(df['ROLL NO'], df['TOTAL'])
